# %% [markdown]
# <a href="https://colab.research.google.com/github/nimesh-mittal/elastic-ml/blob/main/model1_predict_y_for_given_x.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ## Model building

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Model Training

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 39.6803
# Epoch 2/500
# 1/1 [==============================] - 0s 979us/step - loss: 31.2224
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 24.5680
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 19.3326
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 15.2136
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 11.9728
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 9.4231
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.4170
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8387
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5968
# Epoch 11/500
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6197
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8509
# ...

# %% [markdown]
# ## Model Prediction

# %%
print(model.predict([2.0]))
# Out:
# [[6.99963]]
